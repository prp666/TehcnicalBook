# %% [markdown]
# ### Tmux is a very usful tool for running the code background
#
# Here are some useful commands

# %% [markdown]
# ![28ec89a677e8c078334bc489b29cab50.png](attachment:1c759aa5-0944-40be-9ff8-684abaf20eda.png)

# %% [markdown]
# At here, the -s means the source, so create a new task from the source name, if there's no process name as the same ,will create a new one.
#
# The -t means target, which reperesnt the target we want to action. Like acttach in the process, kill this process, for kill all process, we can use: `tmux kill-server`
